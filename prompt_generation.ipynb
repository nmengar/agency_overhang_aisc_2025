# %% [markdown]
# # Prompt Scaffolding Generation

# %% [markdown]
# ### Initialize the setup

# %% [markdown]
# Enviroment Variables
# - AWS_TOKEN
# - HF_KEY
# - GROQ_KEY

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/MyDrive/AI Safety Camp/code"
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/AI Safety Camp/code
# /content/drive/MyDrive/AI Safety Camp/code

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import os

access_token = os.environ.get("HF_TOKEN")
model_name = "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"

tokenizer = AutoTokenizer.from_pretrained(model_name, token=access_token)
model = AutoModelForCausalLM.from_pretrained(model_name, token=access_token)

tokenizer.save_pretrained(f"tokenizers/{model_name}")
model.save_pretrained(f"models/{model_name}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/3.07k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/679 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.55G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]

# %%
# !pip install boto3
# !pip install flash-attn
# !pip install promptbench
# !pip install transformers

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"

tokenizer = AutoTokenizer.from_pretrained(f'/content/drive/MyDrive/AI Safety Camp/code/tokenizers/{model_name}')
model = AutoModelForCausalLM.from_pretrained(f'/content/drive/MyDrive/AI Safety Camp/code/models/{model_name}')

# %%
prompt = "Write a poem on 'Machine Learning'"
pembedding = tokenizer(prompt,return_tensors="pt")
response = tokenizer.decode(model.generate(**pembedding,max_new_tokens=100)[0])
print(response)

# %%
# Run evals
import promptbench as pb
